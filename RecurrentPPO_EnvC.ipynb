# %%
# !pip install -q pogema==1.2.2
# !pip install -q stable_baselines3==2.1.0
# !pip install -q sb3-contrib==2.1.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 69.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 98.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow 2.14.0 requires numpy>=1.23.5, but you have numpy 1.23.1 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 1.9 MB/s eta 0:00:00

# %%
import gymnasium as gym
from pogema import GridConfig

from sb3_contrib import RecurrentPPO
from stable_baselines3.common.evaluation import evaluate_policy

# %%
grid_config = GridConfig(
    size=8,
    density=0.3,
    num_agents=1,
    observation_radius = 3,
    max_episode_steps=128
)

env = gym.make("Pogema-v0",grid_config=grid_config)
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:29: UserWarning: WARN: It seems a Box observation space is an image but the `dtype` is not `np.uint8`, actual type: float32. If the Box observation space is not an image, we recommend flattening the observation to have only a 1D vector.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:34: UserWarning: WARN: It seems a Box observation space is an image but the lower and upper bounds are not [0, 255]. Actual lower bound: -1.0, upper bound: 1.0. Generally, CNN policies assume observations are within that range, so you may encounter an issue if the observation values are not.
#   logger.warn(

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

recurrent_ppo = RecurrentPPO(
    "MlpLstmPolicy",
    env,
    verbose=1,


)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# !pip install -q optuna
# !pip install -q optuna.pruners
# !pip install -q optuna.samplers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 20.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.8 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement optuna.pruners (from versions: none)
# ERROR: No matching distribution found for optuna.pruners
# ERROR: Could not find a version that satisfies the requirement optuna.samplers (from versions: none)
# ERROR: No matching distribution found for optuna.samplers

# %%
from typing import Any
from typing import Dict

import gymnasium
import optuna
from optuna.pruners import MedianPruner
from optuna.samplers import TPESampler
from sb3_contrib import RecurrentPPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
import torch
import torch.nn as nn


N_TRIALS = 100
N_STARTUP_TRIALS = 5
N_EVALUATIONS = 2
N_TIMESTEPS = int(1.2e5)
EVAL_FREQ = int(N_TIMESTEPS / N_EVALUATIONS)
N_EVAL_EPISODES = 3


ENV_ID = "Pogema-v0"

DEFAULT_HYPERPARAMS = {
    "policy": "MlpLstmPolicy",
    "verbose": 1,
    "env": ENV_ID
}

def sample_recurrentppo_params(trial: optuna.Trial) -> Dict[str, Any]:
    """Sampler for RecurrentPPO hyperparameters."""
    gamma = 1.0 - trial.suggest_float("gamma", 0.0001, 0.1, log=True)
    max_grad_norm = trial.suggest_float("max_grad_norm", 0.3, 5.0, log=True)
    gae_lambda = 1.0 - trial.suggest_float("gae_lambda", 0.001, 0.2, log=True)
    n_steps = 2 ** trial.suggest_int("exponent_n_steps", 3, 10)
    learning_rate = trial.suggest_float("lr", 1e-5, 1, log=True)
    ent_coef = trial.suggest_float("ent_coef", 0.00000001, 0.1, log=True)
    ortho_init = trial.suggest_categorical("ortho_init", [False, True])
    net_arch = trial.suggest_categorical("net_arch", ["tiny", "small"])
    activation_fn = trial.suggest_categorical("activation_fn", ["tanh", "relu"])

    # Display true values.
    trial.set_user_attr("gamma_", gamma)
    trial.set_user_attr("gae_lambda_", gae_lambda)
    trial.set_user_attr("n_steps", n_steps)

    net_arch = [
        {"pi": [64], "vf": [64]} if net_arch == "tiny" else {"pi": [64, 64], "vf": [64, 64]}
    ]

    activation_fn = {"tanh": nn.Tanh, "relu": nn.ReLU}[activation_fn]


    return {
        "n_steps": n_steps,
        "gamma": gamma,
        "gae_lambda": gae_lambda,
        "learning_rate": learning_rate,
        "ent_coef": ent_coef,
        "max_grad_norm": max_grad_norm,
        "policy_kwargs": {
            "net_arch": net_arch,
            "activation_fn": activation_fn,
            "ortho_init": ortho_init,
        },
    }

class TrialEvalCallback(EvalCallback):
    """Callback used for evaluating and reporting a trial."""

    def __init__(
        self,
        eval_env: gymnasium.Env,
        trial: optuna.Trial,
        n_eval_episodes: int = 5,
        eval_freq: int = 10000,
        deterministic: bool = True,
        verbose: int = 0,
    ):
        super().__init__(
            eval_env=eval_env,
            n_eval_episodes=n_eval_episodes,
            eval_freq=eval_freq,
            deterministic=deterministic,
            verbose=verbose,
        )
        self.trial = trial
        self.eval_idx = 0
        self.is_pruned = False

    def _on_step(self) -> bool:
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            super()._on_step()
            self.eval_idx += 1
            self.trial.report(self.last_mean_reward, self.eval_idx)
            # Prune trial if need.
            if self.trial.should_prune():
                self.is_pruned = True
                return False
        return True


def objective(trial: optuna.Trial) -> float:
    kwargs = DEFAULT_HYPERPARAMS.copy()
    # Sample hyperparameters.
    kwargs.update(sample_recurrentppo_params(trial))
    # Create the RL model.
    model = RecurrentPPO(**kwargs)
    # Create env used for evaluation.
    eval_env = Monitor(env)
    # Create the callback that will periodically evaluate and report the performance.
    eval_callback = TrialEvalCallback(
        eval_env, trial, n_eval_episodes=N_EVAL_EPISODES, eval_freq=EVAL_FREQ, deterministic=True
    )

    nan_encountered = False
    try:
        model.learn(N_TIMESTEPS, callback=eval_callback)
    except AssertionError as e:
        # Sometimes, random hyperparams can generate NaN.
        print(e)
        nan_encountered = True
    finally:
        # Free memory.
        model.env.close()
        eval_env.close()

    # Tell the optimizer that the trial failed.
    if nan_encountered:
        return float("nan")

    if eval_callback.is_pruned:
        raise optuna.exceptions.TrialPruned()

    return eval_callback.last_mean_reward

if __name__ == "__main__":
    # Set pytorch num threads to 1 for faster training.
    torch.set_num_threads(1)

    sampler = TPESampler(n_startup_trials=N_STARTUP_TRIALS)
    # Do not prune before 1/3 of the max budget is used.
    pruner = MedianPruner(n_startup_trials=N_STARTUP_TRIALS, n_warmup_steps=N_EVALUATIONS // 3)

    study = optuna.create_study(sampler=sampler, pruner=pruner, direction="maximize")
    try:
        study.optimize(objective, n_trials=N_TRIALS, timeout=600)
    except KeyboardInterrupt:
        pass

    print("Number of finished trials: ", len(study.trials))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: ", trial.value)

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))

    print("  User attrs:")
    for key, value in trial.user_attrs.items():
        print("    {}: {}".format(key, value))
# Out:
# [I 2023-11-10 06:41:50,721] A new study created in memory with name: no-name-65836bc7-d436-47c8-8ea5-2be7ea2564e9
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:29: UserWarning: WARN: It seems a Box observation space is an image but the `dtype` is not `np.uint8`, actual type: float32. If the Box observation space is not an image, we recommend flattening the observation to have only a 1D vector.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:34: UserWarning: WARN: It seems a Box observation space is an image but the lower and upper bounds are not [0, 255]. Actual lower bound: -1.0, upper bound: 1.0. Generally, CNN policies assume observations are within that range, so you may encounter an issue if the observation values are not.
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/policies.py:460: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# Using cpu device
# Creating environment from the given name 'Pogema-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.9     |
# |    ep_rew_mean     | 0.524    |
# | time/              |          |
# |    fps             | 241      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 50.2          |
# |    ep_rew_mean          | 0.4           |
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 2             |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 1.3854296e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.61         |
# |    explained_variance   | 0.00584       |
# |    learning_rate        | 3.27e-05      |
# |    loss                 | 0.1           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000333     |
# |    value_loss           | 0.115         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 51.5          |
# |    ep_rew_mean          | 0.356         |
# | time/                   |               |
# |    fps                  | 31            |
# |    iterations           | 3             |
# |    time_elapsed         | 97            |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 2.8464885e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.61         |
# |    explained_variance   | -0.129        |
# |    learning_rate        | 3.27e-05      |
# |    loss                 | 0.0294        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000507     |
# |    value_loss           | 0.045         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.9         |
# |    ep_rew_mean          | 0.375        |
# | time/                   |              |
# |    fps                  | 27           |
# |    iterations           | 4            |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 7.800711e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.61        |
# |    explained_variance   | 0.0511       |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.000985    |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00055     |
# |    value_loss           | 0.0335       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 49.3          |
# |    ep_rew_mean          | 0.39          |
# | time/                   |               |
# |    fps                  | 26            |
# |    iterations           | 5             |
# |    time_elapsed         | 195           |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 2.6593741e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.61         |
# |    explained_variance   | 0.069         |
# |    learning_rate        | 3.27e-05      |
# |    loss                 | 0.0147        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000308     |
# |    value_loss           | 0.0389        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 48.5         |
# |    ep_rew_mean          | 0.4          |
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 6            |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 8.037954e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.61        |
# |    explained_variance   | 0.0614       |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | 0.0247       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000525    |
# |    value_loss           | 0.0354       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.4        |
# |    ep_rew_mean          | 0.42        |
# | time/                   |             |
# |    fps                  | 24          |
# |    iterations           | 7           |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 8.19228e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | -0.0972     |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | 0.00744     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000556   |
# |    value_loss           | 0.0371      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 49.1          |
# |    ep_rew_mean          | 0.36          |
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 8             |
# |    time_elapsed         | 339           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00039422087 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.61         |
# |    explained_variance   | 0.00425       |
# |    learning_rate        | 3.27e-05      |
# |    loss                 | -0.000147     |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00119      |
# |    value_loss           | 0.0206        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.3        |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 9           |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.007129585 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.355      |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | 0.0115      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 0.0136      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 10          |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.002958713 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | -0.343      |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | 0.00224     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 0.0154      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.6        |
# |    ep_rew_mean          | 0.28        |
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 11          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.005440338 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | -0.515      |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.00396    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 53.7          |
# |    ep_rew_mean          | 0.23          |
# | time/                   |               |
# |    fps                  | 23            |
# |    iterations           | 12            |
# |    time_elapsed         | 525           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00039821223 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.59         |
# |    explained_variance   | 0.204         |
# |    learning_rate        | 3.27e-05      |
# |    loss                 | -0.00319      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000946     |
# |    value_loss           | 0.00958       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51           |
# |    ep_rew_mean          | 0.3          |
# | time/                   |              |
# |    fps                  | 23           |
# |    iterations           | 13           |
# |    time_elapsed         | 577          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0010061979 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00529     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 0.00467      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49           |
# |    ep_rew_mean          | 0.36         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 14           |
# |    time_elapsed         | 627          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0014584822 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | -0.0369      |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00446     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 0.0233       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 45.6         |
# |    ep_rew_mean          | 0.42         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 15           |
# |    time_elapsed         | 676          |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0002781179 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00436     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000758    |
# |    value_loss           | 0.017        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44           |
# |    ep_rew_mean          | 0.47         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 16           |
# |    time_elapsed         | 725          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 9.566941e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | -0.145       |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0063      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00073     |
# |    value_loss           | 0.0133       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.7         |
# |    ep_rew_mean          | 0.48         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 17           |
# |    time_elapsed         | 771          |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0003726759 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 0.337        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | 0.000724     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000958    |
# |    value_loss           | 0.0103       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 45.7          |
# |    ep_rew_mean          | 0.47          |
# | time/                   |               |
# |    fps                  | 22            |
# |    iterations           | 18            |
# |    time_elapsed         | 817           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00043644133 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.6          |
# |    explained_variance   | -0.301        |
# |    learning_rate        | 3.27e-05      |
# |    loss                 | 0.000395      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000995     |
# |    value_loss           | 0.0151        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47.8          |
# |    ep_rew_mean          | 0.41          |
# | time/                   |               |
# |    fps                  | 22            |
# |    iterations           | 19            |
# |    time_elapsed         | 863           |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 0.00010938168 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.6          |
# |    explained_variance   | 0.386         |
# |    learning_rate        | 3.27e-05      |
# |    loss                 | -0.00197      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000455     |
# |    value_loss           | 0.00693       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.4         |
# |    ep_rew_mean          | 0.34         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 20           |
# |    time_elapsed         | 912          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0021235016 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00784     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 0.00883      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.9        |
# |    ep_rew_mean          | 0.35        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 21          |
# |    time_elapsed         | 957         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.005142854 |
# |    clip_fraction        | 0.000391    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.0483      |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | 0.00789     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 0.00777     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54.1         |
# |    ep_rew_mean          | 0.29         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 22           |
# |    time_elapsed         | 1004         |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0025261613 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.57        |
# |    explained_variance   | 0.45         |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0157      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 0.0081       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.3        |
# |    ep_rew_mean          | 0.27        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 23          |
# |    time_elapsed         | 1052        |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.009655055 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | -0.415      |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.00948    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00492    |
# |    value_loss           | 0.00931     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54.8         |
# |    ep_rew_mean          | 0.26         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 24           |
# |    time_elapsed         | 1097         |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0022646044 |
# |    clip_fraction        | 0.00645      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0068      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 0.00743      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51          |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 25          |
# |    time_elapsed         | 1143        |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.006456188 |
# |    clip_fraction        | 0.00635     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | 0.00624     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 0.00936     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.3        |
# |    ep_rew_mean          | 0.3         |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 26          |
# |    time_elapsed         | 1193        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010769865 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.00634    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 0.0111      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.2        |
# |    ep_rew_mean          | 0.36        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 27          |
# |    time_elapsed         | 1242        |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.004777574 |
# |    clip_fraction        | 0.0132      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.0078     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 0.00604     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47          |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 28          |
# |    time_elapsed         | 1290        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006531561 |
# |    clip_fraction        | 0.0146      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0524     |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.0184     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00338    |
# |    value_loss           | 0.0105      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.4         |
# |    ep_rew_mean          | 0.34         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 29           |
# |    time_elapsed         | 1338         |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0063734977 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0136      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00315     |
# |    value_loss           | 0.0077       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.9        |
# |    ep_rew_mean          | 0.3         |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 30          |
# |    time_elapsed         | 1386        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008739542 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.129      |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.0024     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.00606     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.1        |
# |    ep_rew_mean          | 0.28        |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 31          |
# |    time_elapsed         | 1435        |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.016172376 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | 0.00172     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00746    |
# |    value_loss           | 0.0047      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.3         |
# |    ep_rew_mean          | 0.24         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 32           |
# |    time_elapsed         | 1482         |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0029378938 |
# |    clip_fraction        | 0.00537      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.456        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0247      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 0.00486      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.1         |
# |    ep_rew_mean          | 0.29         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 33           |
# |    time_elapsed         | 1529         |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0009937234 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00527     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.00582      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.8        |
# |    ep_rew_mean          | 0.3         |
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 34          |
# |    time_elapsed         | 1578        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003949585 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.000746   |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 0.0134      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51         |
# |    ep_rew_mean          | 0.31       |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 35         |
# |    time_elapsed         | 1625       |
# |    total_timesteps      | 35840      |
# | train/                  |            |
# |    approx_kl            | 0.00648846 |
# |    clip_fraction        | 0.0606     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.345      |
# |    learning_rate        | 3.27e-05   |
# |    loss                 | -0.00203   |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.00568   |
# |    value_loss           | 0.0089     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.5         |
# |    ep_rew_mean          | 0.3          |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 36           |
# |    time_elapsed         | 1672         |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0036106615 |
# |    clip_fraction        | 0.00205      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | 0.00153      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 0.00752      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49           |
# |    ep_rew_mean          | 0.35         |
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 37           |
# |    time_elapsed         | 1719         |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0070052994 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.624        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00992     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00613     |
# |    value_loss           | 0.00329      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.7         |
# |    ep_rew_mean          | 0.33         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 38           |
# |    time_elapsed         | 1769         |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0030256389 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0049      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 0.0116       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.9        |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 39          |
# |    time_elapsed         | 1816        |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.003641643 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.0327     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 0.0154      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.9        |
# |    ep_rew_mean          | 0.35        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 40          |
# |    time_elapsed         | 1864        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005803319 |
# |    clip_fraction        | 0.0136      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | 0.00421     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 0.00817     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.8        |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 41          |
# |    time_elapsed         | 1913        |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.006668312 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.00465    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 0.00587     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.7       |
# |    ep_rew_mean          | 0.38       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 42         |
# |    time_elapsed         | 1966       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00476274 |
# |    clip_fraction        | 0.0307     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.554      |
# |    learning_rate        | 3.27e-05   |
# |    loss                 | -0.0055    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00418   |
# |    value_loss           | 0.00678    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 44.6         |
# |    ep_rew_mean          | 0.4          |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 43           |
# |    time_elapsed         | 2017         |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0049083955 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.274        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00578     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00413     |
# |    value_loss           | 0.00879      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.4        |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 44          |
# |    time_elapsed         | 2068        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008093467 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.019      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.00756     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46.6       |
# |    ep_rew_mean          | 0.37       |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 45         |
# |    time_elapsed         | 2115       |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.00688939 |
# |    clip_fraction        | 0.0292     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.24       |
# |    learning_rate        | 3.27e-05   |
# |    loss                 | 0.00113    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00468   |
# |    value_loss           | 0.00849    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.1        |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 46          |
# |    time_elapsed         | 2164        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004918214 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.000465   |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 0.00456     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 48.3         |
# |    ep_rew_mean          | 0.32         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 47           |
# |    time_elapsed         | 2214         |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0060486477 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.388        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0117      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00451     |
# |    value_loss           | 0.00615      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.6         |
# |    ep_rew_mean          | 0.33         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 48           |
# |    time_elapsed         | 2262         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0019783662 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.0638       |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.000914    |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 0.00487      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 48.1         |
# |    ep_rew_mean          | 0.32         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 49           |
# |    time_elapsed         | 2313         |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0043073175 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00668     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00388     |
# |    value_loss           | 0.00911      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.8        |
# |    ep_rew_mean          | 0.29        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 50          |
# |    time_elapsed         | 2360        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004037207 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.0159     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0054     |
# |    value_loss           | 0.00565     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.7         |
# |    ep_rew_mean          | 0.25         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 51           |
# |    time_elapsed         | 2407         |
# |    total_timesteps      | 52224        |
# | train/                  |              |
# |    approx_kl            | 0.0028988088 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.351        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00897     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00485     |
# |    value_loss           | 0.00585      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.2         |
# |    ep_rew_mean          | 0.24         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 52           |
# |    time_elapsed         | 2455         |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0025554127 |
# |    clip_fraction        | 0.00811      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.29         |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | 0.000426     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 0.00364      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.6        |
# |    ep_rew_mean          | 0.2         |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 53          |
# |    time_elapsed         | 2505        |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.009364618 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 3.27e-05    |
# ...
# |    iterations           | 102          |
# |    time_elapsed         | 4948         |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0029253424 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.543        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.011       |
# |    n_updates            | 1010         |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 0.0156       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.9         |
# |    ep_rew_mean          | 0.35         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 103          |
# |    time_elapsed         | 5003         |
# |    total_timesteps      | 105472       |
# | train/                  |              |
# |    approx_kl            | 0.0057411813 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.639        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0038      |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.00607     |
# |    value_loss           | 0.013        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.5         |
# |    ep_rew_mean          | 0.42         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 104          |
# |    time_elapsed         | 5057         |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0029649795 |
# |    clip_fraction        | 0.00811      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | 0.47         |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00644     |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | -0.0051      |
# |    value_loss           | 0.0161       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.1         |
# |    ep_rew_mean          | 0.39         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 105          |
# |    time_elapsed         | 5110         |
# |    total_timesteps      | 107520       |
# | train/                  |              |
# |    approx_kl            | 0.0039896243 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.618        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0184      |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00538     |
# |    value_loss           | 0.0154       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50.1         |
# |    ep_rew_mean          | 0.38         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 106          |
# |    time_elapsed         | 5160         |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0064088292 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0106      |
# |    n_updates            | 1050         |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 0.017        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.9        |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 107         |
# |    time_elapsed         | 5210        |
# |    total_timesteps      | 109568      |
# | train/                  |             |
# |    approx_kl            | 0.005098621 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | 0.00351     |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 0.0132      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.8        |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 108         |
# |    time_elapsed         | 5262        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.006786408 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.0154     |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.00997    |
# |    value_loss           | 0.012       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.1         |
# |    ep_rew_mean          | 0.29         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 109          |
# |    time_elapsed         | 5311         |
# |    total_timesteps      | 111616       |
# | train/                  |              |
# |    approx_kl            | 0.0036324768 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | 0.00471      |
# |    n_updates            | 1080         |
# |    policy_gradient_loss | -0.00544     |
# |    value_loss           | 0.011        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.3         |
# |    ep_rew_mean          | 0.25         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 110          |
# |    time_elapsed         | 5357         |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0035445958 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.39         |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0139      |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.00419     |
# |    value_loss           | 0.0139       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 111         |
# |    time_elapsed         | 5405        |
# |    total_timesteps      | 113664      |
# | train/                  |             |
# |    approx_kl            | 0.003247322 |
# |    clip_fraction        | 0.0158      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.00935    |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 0.00509     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.6         |
# |    ep_rew_mean          | 0.39         |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 112          |
# |    time_elapsed         | 5454         |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0029235405 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0.0839       |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00577     |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | -0.0044      |
# |    value_loss           | 0.0286       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.7         |
# |    ep_rew_mean          | 0.4          |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 113          |
# |    time_elapsed         | 5503         |
# |    total_timesteps      | 115712       |
# | train/                  |              |
# |    approx_kl            | 0.0034801795 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.704        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.0103      |
# |    n_updates            | 1120         |
# |    policy_gradient_loss | -0.00717     |
# |    value_loss           | 0.00893      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.2         |
# |    ep_rew_mean          | 0.4          |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 114          |
# |    time_elapsed         | 5552         |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0028202669 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.513        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00703     |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 0.0117       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46.3         |
# |    ep_rew_mean          | 0.4          |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 115          |
# |    time_elapsed         | 5605         |
# |    total_timesteps      | 117760       |
# | train/                  |              |
# |    approx_kl            | 0.0048585003 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 3.27e-05     |
# |    loss                 | -0.00668     |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | -0.00531     |
# |    value_loss           | 0.01         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 116         |
# |    time_elapsed         | 5654        |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.004470039 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.0246     |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | -0.00691    |
# |    value_loss           | 0.00938     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.2        |
# |    ep_rew_mean          | 0.36        |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 117         |
# |    time_elapsed         | 5702        |
# |    total_timesteps      | 119808      |
# | train/                  |             |
# |    approx_kl            | 0.004046119 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.0206     |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | -0.00695    |
# |    value_loss           | 0.0175      |
# -----------------------------------------
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 128         |
# |    mean_reward          | 0           |
# | time/                   |             |
# |    total_timesteps      | 120000      |
# | train/                  |             |
# |    approx_kl            | 0.007705787 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 3.27e-05    |
# |    loss                 | -0.021      |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00873    |
# |    value_loss           | 0.00641     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.9     |
# |    ep_rew_mean     | 0.38     |
# | time/              |          |
# |    fps             | 21       |
# |    iterations      | 118      |
# |    time_elapsed    | 5751     |
# |    total_timesteps | 120832   |
# ---------------------------------
# [I 2023-11-10 08:18:26,274] Trial 0 finished with value: 0.0 and parameters: {'gamma': 0.00258565880196216, 'max_grad_norm': 0.7836202013398739, 'gae_lambda': 0.018537464817813452, 'exponent_n_steps': 10, 'lr': 3.273413498949338e-05, 'ent_coef': 0.003489100423222157, 'ortho_init': True, 'net_arch': 'tiny', 'activation_fn': 'relu'}. Best is trial 0 with value: 0.0.
# Number of finished trials:  1
# Best trial:
#   Value:  0.0
#   Params:
#     gamma: 0.00258565880196216
#     max_grad_norm: 0.7836202013398739
#     gae_lambda: 0.018537464817813452
#     exponent_n_steps: 10
#     lr: 3.273413498949338e-05
#     ent_coef: 0.003489100423222157
#     ortho_init: True
#     net_arch: tiny
#     activation_fn: relu
#   User attrs:
#     gamma_: 0.9974143411980378
#     gae_lambda_: 0.9814625351821865
#     n_steps: 1024

# %%
val_env = gym.make("Pogema-v0",grid_config=grid_config)

val_recurrent_ppo = RecurrentPPO(
     "MlpLstmPolicy",
    val_env,
    verbose=1,
    gamma=0.9974143411980378,
    learning_rate=3.273413498949338e-05,



)

mean_reward, std_reward = evaluate_policy(
    val_recurrent_ppo,
    val_recurrent_ppo.get_env(),
    deterministic=True,
    n_eval_episodes=20,
)

print(f"mean_reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# mean_reward: 0.10 +/- 0.30

# %%
# Train agent and save it
recurrent_ppo.learn(total_timesteps=int(1.2e5))
recurrent_ppo.save("saved/recurrentppo_baseline")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# |    value_loss           | 0.0175     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 76.7       |
# |    ep_rew_mean          | 0.51       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 701        |
# |    time_elapsed         | 5486       |
# |    total_timesteps      | 89728      |
# | train/                  |            |
# |    approx_kl            | 0.82803416 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.785     |
# |    explained_variance   | -4.91      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0223     |
# |    n_updates            | 7000       |
# |    policy_gradient_loss | 0.00131    |
# |    value_loss           | 0.00776    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.9        |
# |    ep_rew_mean          | 0.51        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 702         |
# |    time_elapsed         | 5490        |
# |    total_timesteps      | 89856       |
# | train/                  |             |
# |    approx_kl            | 0.029451963 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0034     |
# |    n_updates            | 7010        |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.0309      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.9        |
# |    ep_rew_mean          | 0.51        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 703         |
# |    time_elapsed         | 5497        |
# |    total_timesteps      | 89984       |
# | train/                  |             |
# |    approx_kl            | 0.023080224 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.788      |
# |    explained_variance   | 0.0279      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0269     |
# |    n_updates            | 7020        |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 0.0131      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 75.6       |
# |    ep_rew_mean          | 0.53       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 704        |
# |    time_elapsed         | 5506       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.39660347 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.863     |
# |    explained_variance   | 0.476      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0298    |
# |    n_updates            | 7030       |
# |    policy_gradient_loss | -0.0192    |
# |    value_loss           | 0.00405    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 74.3      |
# |    ep_rew_mean          | 0.54      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 705       |
# |    time_elapsed         | 5513      |
# |    total_timesteps      | 90240     |
# | train/                  |           |
# |    approx_kl            | 0.2783787 |
# |    clip_fraction        | 0.162     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.734    |
# |    explained_variance   | -0.041    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.182     |
# |    n_updates            | 7040      |
# |    policy_gradient_loss | 0.0489    |
# |    value_loss           | 0.0239    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 73.3       |
# |    ep_rew_mean          | 0.54       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 706        |
# |    time_elapsed         | 5521       |
# |    total_timesteps      | 90368      |
# | train/                  |            |
# |    approx_kl            | 0.05303784 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.703     |
# |    explained_variance   | 0.364      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0293    |
# |    n_updates            | 7050       |
# |    policy_gradient_loss | -0.0195    |
# |    value_loss           | 0.0168     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.7        |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 707         |
# |    time_elapsed         | 5527        |
# |    total_timesteps      | 90496       |
# | train/                  |             |
# |    approx_kl            | 0.037634164 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0334     |
# |    n_updates            | 7060        |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.7        |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 708         |
# |    time_elapsed         | 5534        |
# |    total_timesteps      | 90624       |
# | train/                  |             |
# |    approx_kl            | 0.029131405 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.713      |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0329     |
# |    n_updates            | 7070        |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 0.0089      |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 74.2     |
# |    ep_rew_mean          | 0.53     |
# | time/                   |          |
# |    fps                  | 16       |
# |    iterations           | 709      |
# |    time_elapsed         | 5542     |
# |    total_timesteps      | 90752    |
# | train/                  |          |
# |    approx_kl            | 0.682882 |
# |    clip_fraction        | 0.175    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.714   |
# |    explained_variance   | -2.5     |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0222  |
# |    n_updates            | 7080     |
# |    policy_gradient_loss | -0.00331 |
# |    value_loss           | 0.00391  |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 75.3       |
# |    ep_rew_mean          | 0.52       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 710        |
# |    time_elapsed         | 5551       |
# |    total_timesteps      | 90880      |
# | train/                  |            |
# |    approx_kl            | 0.43621948 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.785     |
# |    explained_variance   | 0.298      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0157     |
# |    n_updates            | 7090       |
# |    policy_gradient_loss | 0.0124     |
# |    value_loss           | 0.0112     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.6        |
# |    ep_rew_mean          | 0.51        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 711         |
# |    time_elapsed         | 5560        |
# |    total_timesteps      | 91008       |
# | train/                  |             |
# |    approx_kl            | 0.051833306 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | -1.95       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 7100        |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.0041      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.8        |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 712         |
# |    time_elapsed         | 5568        |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.029235272 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | -1.68       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 7110        |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 0.00465     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 78         |
# |    ep_rew_mean          | 0.5        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 713        |
# |    time_elapsed         | 5576       |
# |    total_timesteps      | 91264      |
# | train/                  |            |
# |    approx_kl            | 0.13324614 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.743     |
# |    explained_variance   | -1.27      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0129     |
# |    n_updates            | 7120       |
# |    policy_gradient_loss | 0.00775    |
# |    value_loss           | 0.00124    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 79.2       |
# |    ep_rew_mean          | 0.49       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 714        |
# |    time_elapsed         | 5583       |
# |    total_timesteps      | 91392      |
# | train/                  |            |
# |    approx_kl            | 0.34726244 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.733     |
# |    explained_variance   | 0.206      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00977    |
# |    n_updates            | 7130       |
# |    policy_gradient_loss | 0.00542    |
# |    value_loss           | 0.0298     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.5        |
# |    ep_rew_mean          | 0.49        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 715         |
# |    time_elapsed         | 5591        |
# |    total_timesteps      | 91520       |
# | train/                  |             |
# |    approx_kl            | 0.036067653 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | -0.844      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 7140        |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 0.00175     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.6        |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 716         |
# |    time_elapsed         | 5598        |
# |    total_timesteps      | 91648       |
# | train/                  |             |
# |    approx_kl            | 0.021669338 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.723      |
# |    explained_variance   | 0.38        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0206     |
# |    n_updates            | 7150        |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 0.0203      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.2        |
# |    ep_rew_mean          | 0.51        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 717         |
# |    time_elapsed         | 5605        |
# |    total_timesteps      | 91776       |
# | train/                  |             |
# |    approx_kl            | 0.019441215 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.737      |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 7160        |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 0.0389      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 78.5      |
# |    ep_rew_mean          | 0.51      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 718       |
# |    time_elapsed         | 5612      |
# |    total_timesteps      | 91904     |
# | train/                  |           |
# |    approx_kl            | 1.0473241 |
# |    clip_fraction        | 0.392     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.821    |
# |    explained_variance   | 0.643     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.104     |
# |    n_updates            | 7170      |
# |    policy_gradient_loss | 0.0512    |
# |    value_loss           | 0.016     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 79.7      |
# |    ep_rew_mean          | 0.5       |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 719       |
# |    time_elapsed         | 5618      |
# |    total_timesteps      | 92032     |
# | train/                  |           |
# |    approx_kl            | 0.0706091 |
# |    clip_fraction        | 0.188     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.874    |
# |    explained_variance   | 0.2       |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00869  |
# |    n_updates            | 7180      |
# |    policy_gradient_loss | 0.064     |
# |    value_loss           | 0.0266    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.7        |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 720         |
# |    time_elapsed         | 5626        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.047034536 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.757      |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0372     |
# |    n_updates            | 7190        |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.9        |
# |    ep_rew_mean          | 0.49        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 721         |
# |    time_elapsed         | 5634        |
# |    total_timesteps      | 92288       |
# | train/                  |             |
# |    approx_kl            | 0.038967885 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 7200        |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 0.00378     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.1        |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 722         |
# |    time_elapsed         | 5643        |
# |    total_timesteps      | 92416       |
# | train/                  |             |
# |    approx_kl            | 0.014978403 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00383     |
# |    n_updates            | 7210        |
# |    policy_gradient_loss | 0.00364     |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 82.4       |
# |    ep_rew_mean          | 0.48       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 723        |
# |    time_elapsed         | 5652       |
# |    total_timesteps      | 92544      |
# | train/                  |            |
# |    approx_kl            | 0.05834186 |
# |    clip_fraction        | 0.0766     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.792     |
# |    explained_variance   | 0.45       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00501   |
# |    n_updates            | 7220       |
# |    policy_gradient_loss | -0.0123    |
# |    value_loss           | 0.0105     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83.7       |
# |    ep_rew_mean          | 0.47       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 724        |
# |    time_elapsed         | 5658       |
# |    total_timesteps      | 92672      |
# | train/                  |            |
# |    approx_kl            | 0.12514138 |
# |    clip_fraction        | 0.0773     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.758     |
# |    explained_variance   | 0.264      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00013   |
# |    n_updates            | 7230       |
# |    policy_gradient_loss | -0.00592   |
# |    value_loss           | 0.0285     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.7        |
# |    ep_rew_mean          | 0.46        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 725         |
# |    time_elapsed         | 5667        |
# |    total_timesteps      | 92800       |
# | train/                  |             |
# |    approx_kl            | 0.012884833 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | -4.44       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0189     |
# |    n_updates            | 7240        |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.00947     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.8       |
# |    ep_rew_mean          | 0.45       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 726        |
# |    time_elapsed         | 5676       |
# |    total_timesteps      | 92928      |
# | train/                  |            |
# |    approx_kl            | 0.06656248 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.918     |
# |    explained_variance   | 0.633      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0185    |
# |    n_updates            | 7250       |
# |    policy_gradient_loss | -0.0141    |
# |    value_loss           | 0.0013     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.8       |
# |    ep_rew_mean          | 0.45       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 727        |
# |    time_elapsed         | 5683       |
# |    total_timesteps      | 93056      |
# | train/                  |            |
# |    approx_kl            | 0.28798825 |
# |    clip_fraction        | 0.0977     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.894     |
# |    explained_variance   | -1.27      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0323    |
# |    n_updates            | 7260       |
# |    policy_gradient_loss | -0.0164    |
# |    value_loss           | 0.00105    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86          |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 728         |
# |    time_elapsed         | 5691        |
# |    total_timesteps      | 93184       |
# | train/                  |             |
# |    approx_kl            | 0.032211058 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.829      |
# |    explained_variance   | -2          |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 7270        |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 0.000605    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86         |
# |    ep_rew_mean          | 0.45       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 729        |
# |    time_elapsed         | 5696       |
# |    total_timesteps      | 93312      |
# | train/                  |            |
# |    approx_kl            | 0.06082347 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.829     |
# |    explained_variance   | 0.0904     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0103    |
# |    n_updates            | 7280       |
# |    policy_gradient_loss | -0.0158    |
# |    value_loss           | 0.0301     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86         |
# |    ep_rew_mean          | 0.45       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 730        |
# |    time_elapsed         | 5704       |
# |    total_timesteps      | 93440      |
# | train/                  |            |
# |    approx_kl            | 0.24022067 |
# |    clip_fraction        | 0.0781     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.803     |
# |    explained_variance   | 0.736      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0171    |
# |    n_updates            | 7290       |
# |    policy_gradient_loss | -0.00591   |
# |    value_loss           | 0.00198    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86          |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 731         |
# |    time_elapsed         | 5709        |
# |    total_timesteps      | 93568       |
# | train/                  |             |
# |    approx_kl            | 0.022073679 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | -3.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0235     |
# |    n_updates            | 7300        |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86         |
# |    ep_rew_mean          | 0.45       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 732        |
# |    time_elapsed         | 5716       |
# |    total_timesteps      | 93696      |
# | train/                  |            |
# |    approx_kl            | 0.02721677 |
# |    clip_fraction        | 0.0867     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.813     |
# |    explained_variance   | 0.591      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0326    |
# |    n_updates            | 7310       |
# |    policy_gradient_loss | -0.0183    |
# |    value_loss           | 0.000723   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.1       |
# |    ep_rew_mean          | 0.46       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 733        |
# |    time_elapsed         | 5721       |
# |    total_timesteps      | 93824      |
# | train/                  |            |
# |    approx_kl            | 0.04027253 |
# |    clip_fraction        | 0.0922     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.75      |
# |    explained_variance   | 0.194      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00403   |
# |    n_updates            | 7320       |
# |    policy_gradient_loss | -0.00322   |
# |    value_loss           | 0.0303     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.1       |
# |    ep_rew_mean          | 0.46       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 734        |
# |    time_elapsed         | 5731       |
# |    total_timesteps      | 93952      |
# | train/                  |            |
# |    approx_kl            | 0.09049408 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.888     |
# |    explained_variance   | 0.133      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.014     |
# |    n_updates            | 7330       |
# |    policy_gradient_loss | -0.0167    |
# |    value_loss           | 0.0325     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.6        |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 735         |
# |    time_elapsed         | 5738        |
# |    total_timesteps      | 94080       |
# | train/                  |             |
# |    approx_kl            | 0.049271893 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.817      |
# |    explained_variance   | -0.765      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 7340        |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 82.6       |
# |    ep_rew_mean          | 0.48       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 736        |
# |    time_elapsed         | 5743       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.15359393 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.728     |
# |    explained_variance   | 0.42       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0148    |
# |    n_updates            | 7350       |
# |    policy_gradient_loss | -0.0211    |
# |    value_loss           | 0.0559     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83.2       |
# |    ep_rew_mean          | 0.47       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 737        |
# |    time_elapsed         | 5749       |
# |    total_timesteps      | 94336      |
# | train/                  |            |
# |    approx_kl            | 0.05210165 |
# |    clip_fraction        | 0.0711     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.781     |
# |    explained_variance   | -4.2       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0126    |
# |    n_updates            | 7360       |
# |    policy_gradient_loss | -0.00591   |
# |    value_loss           | 0.00348    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 82.2      |
# |    ep_rew_mean          | 0.48      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 738       |
# |    time_elapsed         | 5756      |
# |    total_timesteps      | 94464     |
# | train/                  |           |
# |    approx_kl            | 0.1429529 |
# |    clip_fraction        | 0.16      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.735    |
# |    explained_variance   | -8.23     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0203   |
# |    n_updates            | 7370      |
# |    policy_gradient_loss | -0.0123   |
# |    value_loss           | 0.013     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.2        |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 739         |
# |    time_elapsed         | 5763        |
# |    total_timesteps      | 94592       |
# | train/                  |             |
# |    approx_kl            | 0.057136834 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0329     |
# |    n_updates            | 7380        |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 0.0188      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 82.2      |
# |    ep_rew_mean          | 0.48      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 740       |
# |    time_elapsed         | 5771      |
# |    total_timesteps      | 94720     |
# | train/                  |           |
# |    approx_kl            | 0.0288031 |
# |    clip_fraction        | 0.171     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.79     |
# |    explained_variance   | 0.131     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0301   |
# |    n_updates            | 7390      |
# |    policy_gradient_loss | -0.0204   |
# |    value_loss           | 0.00908   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.2        |
# |    ep_rew_mean          | 0.48        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 741         |
# |    time_elapsed         | 5780        |
# |    total_timesteps      | 94848       |
# | train/                  |             |
# |    approx_kl            | 0.024991404 |
# |    clip_fraction        | 0.0984      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | -1.07       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0299     |
# |    n_updates            | 7400        |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.6       |
# |    ep_rew_mean          | 0.49       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 742        |
# |    time_elapsed         | 5788       |
# |    total_timesteps      | 94976      |
# | train/                  |            |
# |    approx_kl            | 0.02073992 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.791     |
# |    explained_variance   | -1.02      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0234    |
# |    n_updates            | 7410       |
# |    policy_gradient_loss | -0.007     |
# |    value_loss           | 0.00325    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.4       |
# |    ep_rew_mean          | 0.49       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 743        |
# |    time_elapsed         | 5795       |
# |    total_timesteps      | 95104      |
# | train/                  |            |
# |    approx_kl            | 0.06274474 |
# |    clip_fraction        | 0.0773     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.711     |
# |    explained_variance   | -0.0259    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0168    |
# |    n_updates            | 7420       |
# |    policy_gradient_loss | -0.00882   |
# |    value_loss           | 0.0311     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 80.2       |
# |    ep_rew_mean          | 0.5        |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 744        |
# |    time_elapsed         | 5800       |
# |    total_timesteps      | 95232      |
# | train/                  |            |
# |    approx_kl            | 0.21525605 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.756     |
# |    explained_variance   | 0.406      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0167    |
# |    n_updates            | 7430       |
# |    policy_gradient_loss | -0.0143    |
# |    value_loss           | 0.0169     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 79.5       |
# |    ep_rew_mean          | 0.51       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 745        |
# |    time_elapsed         | 5806       |
# |    total_timesteps      | 95360      |
# | train/                  |            |
# |    approx_kl            | 0.07071866 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.776     |
# |    explained_variance   | 0.319      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.02      |
# |    n_updates            | 7440       |
# |    policy_gradient_loss | -0.0178    |
# |    value_loss           | 0.0208     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.6        |
# |    ep_rew_mean          | 0.53        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 746         |
# |    time_elapsed         | 5815        |
# |    total_timesteps      | 95488       |
# | train/                  |             |
# |    approx_kl            | 0.021742636 |
# |    clip_fraction        | 0.0664      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.767      |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0187     |
# |    n_updates            | 7450        |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.0106      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 77.7       |
# |    ep_rew_mean          | 0.53       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 747        |
# |    time_elapsed         | 5821       |
# |    total_timesteps      | 95616      |
# | train/                  |            |
# |    approx_kl            | 0.17509179 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.772     |
# |    explained_variance   | 0.315      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0243    |
# |    n_updates            | 7460       |
# |    policy_gradient_loss | -0.0221    |
# |    value_loss           | 0.0458     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 77.7       |
# |    ep_rew_mean          | 0.53       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 748        |
# |    time_elapsed         | 5827       |
# |    total_timesteps      | 95744      |
# | train/                  |            |
# |    approx_kl            | 0.11602649 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.722     |
# |    explained_variance   | 0.397      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00336   |
# |    n_updates            | 7470       |
# |    policy_gradient_loss | -0.00818   |
# |    value_loss           | 0.0163     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.7        |
# |    ep_rew_mean          | 0.53        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 749         |
# |    time_elapsed         | 5835        |
# |    total_timesteps      | 95872       |
# | train/                  |             |
# |    approx_kl            | 0.023169108 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.651      |
# |    explained_variance   | -0.283      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0173     |
# |    n_updates            | 7480        |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 0.015       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.4        |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 750         |
# |    time_elapsed         | 5843        |
# |    total_timesteps      | 96000       |
# | train/                  |             |
# |    approx_kl            | 0.012773728 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.746      |
# |    explained_variance   | -0.152      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0367     |
# |    n_updates            | 7490        |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 0.00895     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.2        |
# |    ep_rew_mean          | 0.53        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 751         |
# |    time_elapsed         | 5849        |
# |    total_timesteps      | 96128       |
# | train/                  |             |
# |    approx_kl            | 0.061555777 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.713      |
# |    explained_variance   | 0.506       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 7500        |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 0.0164      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.2        |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 752         |
# |    time_elapsed         | 5855        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014835345 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | -1.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 7510        |
# |    policy_gradient_loss | -0.008      |
# |    value_loss           | 0.00267     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 78.2       |
# |    ep_rew_mean          | 0.54       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 753        |
# |    time_elapsed         | 5863       |
# |    total_timesteps      | 96384      |
# | train/                  |            |
# |    approx_kl            | 0.26797166 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.658     |
# |    explained_variance   | -0.108     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0184    |
# |    n_updates            | 7520       |
# |    policy_gradient_loss | -0.0158    |
# |    value_loss           | 0.0193     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.2        |
# |    ep_rew_mean          | 0.53        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 754         |
# |    time_elapsed         | 5868        |
# |    total_timesteps      | 96512       |
# | train/                  |             |
# |    approx_kl            | 0.039668687 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | -0.972      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.023      |
# |    n_updates            | 7530        |
# |    policy_gradient_loss | -0.00783    |
# |    value_loss           | 0.00341     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 79.5       |
# |    ep_rew_mean          | 0.53       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 755        |
# |    time_elapsed         | 5875       |
# |    total_timesteps      | 96640      |
# | train/                  |            |
# |    approx_kl            | 0.03243035 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.733     |
# |    explained_variance   | 0.138      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.022     |
# |    n_updates            | 7540       |
# |    policy_gradient_loss | -0.00725   |
# |    value_loss           | 0.00415    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 79.5       |
# |    ep_rew_mean          | 0.53       |
# ...
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 0.041       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.9        |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 921         |
# |    time_elapsed         | 7125        |
# |    total_timesteps      | 117888      |
# | train/                  |             |
# |    approx_kl            | 0.053448945 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | -3.25       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 9200        |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.00258     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 84.9       |
# |    ep_rew_mean          | 0.43       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 922        |
# |    time_elapsed         | 7133       |
# |    total_timesteps      | 118016     |
# | train/                  |            |
# |    approx_kl            | 0.16524869 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.522     |
# |    explained_variance   | -5.74      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00393   |
# |    n_updates            | 9210       |
# |    policy_gradient_loss | 0.00333    |
# |    value_loss           | 0.00129    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.9        |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 923         |
# |    time_elapsed         | 7139        |
# |    total_timesteps      | 118144      |
# | train/                  |             |
# |    approx_kl            | 0.067511335 |
# |    clip_fraction        | 0.0844      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | -3.65       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0277     |
# |    n_updates            | 9220        |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.00128     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.5        |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 924         |
# |    time_elapsed         | 7146        |
# |    total_timesteps      | 118272      |
# | train/                  |             |
# |    approx_kl            | 0.046251908 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.515      |
# |    explained_variance   | -0.83       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -7.42e-05   |
# |    n_updates            | 9230        |
# |    policy_gradient_loss | -0.000831   |
# |    value_loss           | 0.000639    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.7       |
# |    ep_rew_mean          | 0.42       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 925        |
# |    time_elapsed         | 7153       |
# |    total_timesteps      | 118400     |
# | train/                  |            |
# |    approx_kl            | 0.01526959 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.526     |
# |    explained_variance   | 0.0812     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00997   |
# |    n_updates            | 9240       |
# |    policy_gradient_loss | -0.00848   |
# |    value_loss           | 0.0204     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85         |
# |    ep_rew_mean          | 0.43       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 926        |
# |    time_elapsed         | 7161       |
# |    total_timesteps      | 118528     |
# | train/                  |            |
# |    approx_kl            | 0.04578899 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.527     |
# |    explained_variance   | -2.55      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0323    |
# |    n_updates            | 9250       |
# |    policy_gradient_loss | -0.0209    |
# |    value_loss           | 0.00104    |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 86       |
# |    ep_rew_mean          | 0.42     |
# | time/                   |          |
# |    fps                  | 16       |
# |    iterations           | 927      |
# |    time_elapsed         | 7166     |
# |    total_timesteps      | 118656   |
# | train/                  |          |
# |    approx_kl            | 0.123001 |
# |    clip_fraction        | 0.127    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.589   |
# |    explained_variance   | 0.689    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0128  |
# |    n_updates            | 9260     |
# |    policy_gradient_loss | -0.016   |
# |    value_loss           | 0.0168   |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.9        |
# |    ep_rew_mean          | 0.44        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 928         |
# |    time_elapsed         | 7174        |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.028907077 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | -0.0973     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 9270        |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.00212     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.9       |
# |    ep_rew_mean          | 0.43       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 929        |
# |    time_elapsed         | 7180       |
# |    total_timesteps      | 118912     |
# | train/                  |            |
# |    approx_kl            | 0.06751981 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.502     |
# |    explained_variance   | -0.203     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00422    |
# |    n_updates            | 9280       |
# |    policy_gradient_loss | -0.00746   |
# |    value_loss           | 0.0762     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.7        |
# |    ep_rew_mean          | 0.44        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 930         |
# |    time_elapsed         | 7190        |
# |    total_timesteps      | 119040      |
# | train/                  |             |
# |    approx_kl            | 0.005603805 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.498      |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00669    |
# |    n_updates            | 9290        |
# |    policy_gradient_loss | -0.00384    |
# |    value_loss           | 0.00931     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.3        |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 931         |
# |    time_elapsed         | 7199        |
# |    total_timesteps      | 119168      |
# | train/                  |             |
# |    approx_kl            | 0.028992314 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.496      |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 9300        |
# |    policy_gradient_loss | 0.000614    |
# |    value_loss           | 0.00541     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.6        |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 932         |
# |    time_elapsed         | 7208        |
# |    total_timesteps      | 119296      |
# | train/                  |             |
# |    approx_kl            | 0.022761967 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.457      |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 9310        |
# |    policy_gradient_loss | -0.00701    |
# |    value_loss           | 0.00377     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.2        |
# |    ep_rew_mean          | 0.44        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 933         |
# |    time_elapsed         | 7215        |
# |    total_timesteps      | 119424      |
# | train/                  |             |
# |    approx_kl            | 0.034077674 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.423      |
# |    explained_variance   | -0.0273     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000395    |
# |    n_updates            | 9320        |
# |    policy_gradient_loss | -0.00446    |
# |    value_loss           | 0.0324      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 86.3      |
# |    ep_rew_mean          | 0.43      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 934       |
# |    time_elapsed         | 7224      |
# |    total_timesteps      | 119552    |
# | train/                  |           |
# |    approx_kl            | 2.8184972 |
# |    clip_fraction        | 0.383     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.397    |
# |    explained_variance   | 0.281     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.202     |
# |    n_updates            | 9330      |
# |    policy_gradient_loss | 0.11      |
# |    value_loss           | 0.0233    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.3        |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 935         |
# |    time_elapsed         | 7232        |
# |    total_timesteps      | 119680      |
# | train/                  |             |
# |    approx_kl            | 0.060630888 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.363      |
# |    explained_variance   | -0.202      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00765    |
# |    n_updates            | 9340        |
# |    policy_gradient_loss | 0.0283      |
# |    value_loss           | 0.00147     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86.3       |
# |    ep_rew_mean          | 0.43       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 936        |
# |    time_elapsed         | 7241       |
# |    total_timesteps      | 119808     |
# | train/                  |            |
# |    approx_kl            | 0.09384424 |
# |    clip_fraction        | 0.0719     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.381     |
# |    explained_variance   | -10        |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0248    |
# |    n_updates            | 9350       |
# |    policy_gradient_loss | -0.0119    |
# |    value_loss           | 0.00244    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 86.3      |
# |    ep_rew_mean          | 0.43      |
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 937       |
# |    time_elapsed         | 7250      |
# |    total_timesteps      | 119936    |
# | train/                  |           |
# |    approx_kl            | 0.2829283 |
# |    clip_fraction        | 0.075     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.367    |
# |    explained_variance   | 0.429     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.021     |
# |    n_updates            | 9360      |
# |    policy_gradient_loss | 0.00491   |
# |    value_loss           | 0.000536  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.8        |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 938         |
# |    time_elapsed         | 7259        |
# |    total_timesteps      | 120064      |
# | train/                  |             |
# |    approx_kl            | 0.052357905 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.392      |
# |    explained_variance   | -4.39       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00991    |
# |    n_updates            | 9370        |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 0.00217     |
# -----------------------------------------
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/save_util.py:278: UserWarning: Path 'saved' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
def evaluate_success_rate(model, env, num_episodes=100):
    success_count = 0
    step_array = []
    for _ in range(num_episodes):
        obs = env.reset()

        # Check if observation is a tuple and extract the first element if true.
        if isinstance(obs, tuple):
            obs = obs[0]
        max_step = 128
        steps_taken = 0
        done = truncated = False
        while not done and max_step > 0:
            action, _ = model.predict(obs)
            next_obs, reward, done, truncated, info = env.step(action)
            print(action,max_step,success_count,done)
            max_step -= 1
            steps_taken += 1
            # Check if next_obs is a tuple and extract the first element if true.
            if isinstance(next_obs, tuple):
                next_obs = next_obs[0]
            obs = next_obs

            # Check if agent was successful in that episode.
            if done:
                success_count += 1
                step_array.append(steps_taken)
                break

    success_rate = success_count / num_episodes
    return success_rate, step_array

success_rate,step_array = evaluate_success_rate(recurrent_ppo, env)
print(f"Agent Success Rate: {success_rate * 100:.2f}%")
print(f"steps to termination : {step_array}")

# Calculate the average steps to termination
average_steps = sum(step_array) / len(step_array)
print("Average steps to termination:", average_steps)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 2 53 9 False
# 2 52 9 False
# 2 51 9 False
# 2 50 9 False
# 2 49 9 False
# 2 48 9 False
# 2 47 9 False
# 2 46 9 False
# 2 45 9 False
# 1 44 9 False
# 2 43 9 False
# 3 42 9 False
# 4 41 9 False
# 2 40 9 False
# 2 39 9 False
# 2 38 9 False
# 1 37 9 False
# 2 36 9 False
# 2 35 9 False
# 2 34 9 False
# 2 33 9 False
# 2 32 9 False
# 2 31 9 False
# 2 30 9 False
# 2 29 9 False
# 4 28 9 False
# 1 27 9 False
# 1 26 9 False
# 4 25 9 False
# 2 24 9 False
# 2 23 9 False
# 2 22 9 False
# 2 21 9 False
# 2 20 9 False
# 2 19 9 False
# 2 18 9 False
# 1 17 9 False
# 4 16 9 False
# 4 15 9 False
# 2 14 9 False
# 3 13 9 False
# 2 12 9 False
# 3 11 9 False
# 3 10 9 False
# 3 9 9 False
# 3 8 9 False
# 3 7 9 False
# 3 6 9 False
# 3 5 9 False
# 3 4 9 False
# 3 3 9 False
# 3 2 9 False
# 3 1 9 False
# 2 100 9 False
# 2 99 9 False
# 2 98 9 False
# 2 97 9 False
# 2 96 9 False
# 2 95 9 False
# 1 94 9 False
# 2 93 9 False
# 2 92 9 False
# 2 91 9 False
# 3 90 9 False
# 2 89 9 False
# 2 88 9 False
